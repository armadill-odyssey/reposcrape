# %%
# import pandas as pd

filename = '/Users/coreysery/Developer/School/CSC3130/reposcrape/data/2017-02-09.github.json'
# data = pd.read_json(filename)

import pandas as pd
import json
import os

# Reading the json as a dict
with open(filename) as json_data:
    data = json.load(json_data)

# %%
# Out:
# {'1C Enterprise': [{'author': 'xDrivenDevelopment',
#    'desc': 'precommit1c',
#    'forks': 86,
#    'lang': '1C Enterprise',
#    'repo': 'precommit1c',
#    'repoLink': '/xDrivenDevelopment/precommit1c',
#    'stars': 91,
#    'starsToday': 0},
#   {'author': 'silverbulleters',
#    'desc': 'BDD for 1C:Enterprise inspired by Cucumber',
#    'forks': 61,
#    'lang': '1C Enterprise',
#    'repo': 'vanessa-behavior',
#    'repoLink': '/silverbulleters/vanessa-behavior',
#    'stars': 216,
#    'starsToday': 0},
#   {'author': 'xDrivenDevelopment',
#    'desc': 'Unit testing tools for 1C:Enterprise 8 platform (http://v8.1c.ru)',
#    'forks': 66,
#    'lang': '1C Enterprise',
#    'repo': 'xUnitFor1C',
#    'repoLink': '/xDrivenDevelopment/xUnitFor1C',
#    'stars': 178,
#    'starsToday': 0},
#   {'author': 'EvilBeaver',
#    'desc': 'Библиотека полезных скриптов для 1Script',
#    'forks': 48,
#    'lang': '1C Enterprise',
#    'repo': 'oscript-library',
#    'repoLink': '/EvilBeaver/oscript-library',
#    'stars': 93,
#    'starsToday': 0},
#   {'author': '1C-Company',
#    'desc': '',
#    'forks': 34,
#    'lang': '1C Enterprise',
#    'repo': 'dt-demo-configuration',
#    'repoLink': '/1C-Company/dt-demo-configuration',
#    'stars': 59,
#    'starsToday': 0},
#   {'author': 'xDrivenDevelopment',
#    'desc': 'Syntax definition rules for 1C:Enterprise 8 in TextMate format',
#    'forks': 11,
#    'lang': '1C Enterprise',
#    'repo': '1c-syntax',
#    'repoLink': '/xDrivenDevelopment/1c-syntax',
#    'stars': 34,
#    'starsToday': 0},
#   {'author': 'oscript-library',
#    'desc': 'Синхронизация хранилища 1С с репозиторием git',
#    'forks': 17,
#    'lang': '1C Enterprise',
#    'repo': 'gitsync',
#    'repoLink': '/oscript-library/gitsync',
#    'stars': 32,
#    'starsToday': 0},
#   {'author': 'silverbulleters',
#    'desc': 'утилита автоматизация базовых операций разработчика 1С',
#    'forks': 12,
#    'lang': '1C Enterprise',
#    'repo': 'vanessa-runner',
#    'repoLink': '/silverbulleters/vanessa-runner',
#    'stars': 32,
#    'starsToday': 0},
#   {'author': 'oscript-library',
#    'desc': 'Сборка тиражируемых дистрибутивов 1С',
#    'forks': 5,
#    'lang': '1C Enterprise',
#    'repo': 'packman',
#    'repoLink': '/oscript-library/packman',
#    'stars': 30,
#    'starsToday': 0},
#   {'author': 'ctuning',
#    'desc': 'Platforms participating in experiment crowdsourcing, and their features',
#    'forks': 0,
#    'lang': '1C Enterprise',
#    'repo': 'ck-crowdtuning-platforms',
#    'repoLink': '/ctuning/ck-crowdtuning-platforms',
#    'stars': 30,
#    'starsToday': 0},
#   {'author': 'BlizD',
#    'desc': 'Конфигурация "Управление задачами" с использованием библиотеки стандартных подсистем. Канбан доска. Загрузка изменений из хранилища 1с.',
#    'forks': 10,
#    'lang': '1C Enterprise',
#    'repo': 'Tasks',
#    'repoLink': '/BlizD/Tasks',
#    'stars': 26,
#    'starsToday': 0},
#   {'author': 'oscript-library',
#    'desc': 'Continuous Delivery for 1C:Enterprise',
#    'forks': 10,
#    'lang': '1C Enterprise',
#    'repo': 'deployka',
#    'repoLink': '/oscript-library/deployka',
#    'stars': 24,
#    'starsToday': 0},
#   {'author': 'a-sitnikov',
#    'desc': 'Набор тестов для конфигурации 1C:ERP 2',
#    'forks': 8,
#    'lang': '1C Enterprise',
#    'repo': 'erp2_xtests',
#    'repoLink': '/a-sitnikov/erp2_xtests',
#    'stars': 24,
#    'starsToday': 0},
#   {'author': 'ret-Phoenix',
#    'desc': 'Компонент для работы с базой sqlite из onescript',
#    'forks': 3,
#    'lang': '1C Enterprise',
#    'repo': 'oscript-sql',
#    'repoLink': '/ret-Phoenix/oscript-sql',
#    'stars': 24,
#    'starsToday': 0},
#   {'author': 'tormozit',
#    'desc': 'Runtime Developer Tools for 1C platform 8.2+',
#    'forks': 4,
#    'lang': '1C Enterprise',
#    'repo': '1C-Runtime-Developer-Tools',
#    'repoLink': '/tormozit/1C-Runtime-Developer-Tools',
#    'stars': 23,
#    'starsToday': 0},
#   {'author': 'silverbulleters',
#    'desc': 'EffectCup and SCRUM for 1C:Enterprise',
#    'forks': 2,
#    'lang': '1C Enterprise',
#    'repo': 'vanessa-agiler',
#    'repoLink': '/silverbulleters/vanessa-agiler',
#    'stars': 20,
#    'starsToday': 0},
#   {'author': 'silverbulleters',
#    'desc': 'репозиторий для нового процесса разработки',
#    'forks': 8,
#    'lang': '1C Enterprise',
#    'repo': 'vanessa-behavior-new',
#    'repoLink': '/silverbulleters/vanessa-behavior-new',
#    'stars': 13,
#    'starsToday': 0},
#   {'author': 'oscript-library',
#    'desc': 'Управление запуском 1С из командной строки',
#    'forks': 5,
#    'lang': '1C Enterprise',
#    'repo': 'v8runner',
#    'repoLink': '/oscript-library/v8runner',
#    'stars': 12,
#    'starsToday': 0},
#   {'author': 'nixel2007',
#    'desc': '',
#    'forks': 4,
#    'lang': '1C Enterprise',
#    'repo': 'gitrunner',
#    'repoLink': '/nixel2007/gitrunner',
#    'stars': 11,
#    'starsToday': 0},
#   {'author': 'silverbulleters',
#    'desc': 'DEPRECATED - use gitsync',
#    'forks': 5,
#    'lang': '1C Enterprise',
#    'repo': 'vanessa-unpack',
#    'repoLink': '/silverbulleters/vanessa-unpack',
#    'stars': 11,
#    'starsToday': 0},
#   {'author': 'artbear',
#    'desc': '',
#    'forks': 6,
#    'lang': '1C Enterprise',
#    'repo': '1bdd',
#    'repoLink': '/artbear/1bdd',
#    'stars': 11,
#    'starsToday': 0},
#   {'author': 'pbazeliuk',
#    'desc': 'Расширение процессора вывода результата компоновки данных',
#    'forks': 4,
#    'lang': '1C Enterprise',
#    'repo': 'OutputProcessorExtension',
#    'repoLink': '/pbazeliuk/OutputProcessorExtension',
#    'stars': 11,
#    'starsToday': 0},
#   {'author': 'oscript-library',
#    'desc': 'Пакетный менеджер OneScript',
#    'forks': 6,
#    'lang': '1C Enterprise',
#    'repo': 'opm',
#    'repoLink': '/oscript-library/opm',
#    'stars': 9,
#    'starsToday': 0},
#   {'author': 'oscript-library',
#    'desc': 'Класс, позволяющий отправлять уведомления по SMS и в SLACK',
#    'forks': 3,
#    'lang': '1C Enterprise',
#    'repo': 'messenger',
#    'repoLink': '/oscript-library/messenger',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'Eurospider',
#    'desc': 'script to build a firewall appliance based on OpenBSD',
#    'forks': 4,
#    'lang': '1C Enterprise',
#    'repo': 'OpenBSD-firewall',
#    'repoLink': '/Eurospider/OpenBSD-firewall',
#    'stars': 7,
#    'starsToday': 0}],
#  'ABAP': [{'author': 'larshp',
#    'desc': 'Git client for ABAP',
#    'forks': 57,
#    'lang': 'ABAP',
#    'repo': 'abapGit',
#    'repoLink': '/larshp/abapGit',
#    'stars': 160,
#    'starsToday': 0},
#   {'author': 'emilybache',
#    'desc': 'Starting code for a Refactoring Code Kata on the Tennis rules',
#    'forks': 236,
#    'lang': 'ABAP',
#    'repo': 'Tennis-Refactoring-Kata',
#    'repoLink': '/emilybache/Tennis-Refactoring-Kata',
#    'stars': 123,
#    'starsToday': 0},
#   {'author': 'rvanmil',
#    'desc': 'ABAP Object-oriented programming Library',
#    'forks': 27,
#    'lang': 'ABAP',
#    'repo': 'ABAP-OOP-Library',
#    'repoLink': '/rvanmil/ABAP-OOP-Library',
#    'stars': 51,
#    'starsToday': 0},
#   {'author': 'abramsba',
#    'desc': 'An ABAP reference examples for common technical tasks',
#    'forks': 12,
#    'lang': 'ABAP',
#    'repo': 'AbapExamples',
#    'repoLink': '/abramsba/AbapExamples',
#    'stars': 49,
#    'starsToday': 0},
#   {'author': 'epeterson320',
#    'desc': 'ABAP Logging as painless as any other language',
#    'forks': 10,
#    'lang': 'ABAP',
#    'repo': 'ABAP-Logger',
#    'repoLink': '/epeterson320/ABAP-Logger',
#    'stars': 43,
#    'starsToday': 0},
#   {'author': 'moreus',
#    'desc': '',
#    'forks': 7,
#    'lang': 'ABAP',
#    'repo': 'ABAPDesignPattern',
#    'repoLink': '/moreus/ABAPDesignPattern',
#    'stars': 29,
#    'starsToday': 0},
#   {'author': 'larshp',
#    'desc': 'Open source checks for SAP Code Inspector / ABAP Test Cockpit',
#    'forks': 12,
#    'lang': 'ABAP',
#    'repo': 'abapOpenChecks',
#    'repoLink': '/larshp/abapOpenChecks',
#    'stars': 28,
#    'starsToday': 0},
#   {'author': 'cesar-sap',
#    'desc': 'JSON adapter for ABAP Function Modules.',
#    'forks': 14,
#    'lang': 'ABAP',
#    'repo': 'abap_fm_json',
#    'repoLink': '/cesar-sap/abap_fm_json',
#    'stars': 26,
#    'starsToday': 0},
#   {'author': 'mauriciolauffer',
#    'desc': 'ABAP Code sample',
#    'forks': 10,
#    'lang': 'ABAP',
#    'repo': 'ABAP',
#    'repoLink': '/mauriciolauffer/ABAP',
#    'stars': 26,
#    'starsToday': 0},
#   {'author': 'rvanmil',
#    'desc': 'ABAP Regular Expressions Training',
#    'forks': 9,
#    'lang': 'ABAP',
#    'repo': 'ABAP-Regex-Training',
#    'repoLink': '/rvanmil/ABAP-Regex-Training',
#    'stars': 19,
#    'starsToday': 0},
#   {'author': 'larshp',
#    'desc': 'Visualize complex object hierarchies using debugger script',
#    'forks': 1,
#    'lang': 'ABAP',
#    'repo': 'ABAP-Object-Visualizer',
#    'repoLink': '/larshp/ABAP-Object-Visualizer',
#    'stars': 14,
#    'starsToday': 0},
#   {'author': 'fidley',
#    'desc': 'FALV - Fast ALV Grid',
#    'forks': 2,
#    'lang': 'ABAP',
#    'repo': 'falv',
#    'repoLink': '/fidley/falv',
#    'stars': 13,
#    'starsToday': 0},
#   {'author': 'sbcgua',
#    'desc': 'SAP ABAP tool for unit testing',
#    'forks': 2,
#    'lang': 'ABAP',
#    'repo': 'mockup_loader',
#    'repoLink': '/sbcgua/mockup_loader',
#    'stars': 12,
#    'starsToday': 0},
#   {'author': 'Sumu-Ning',
#    'desc': 'ABAP Utilities for AES/Rijndael encryption, decryption',
#    'forks': 3,
#    'lang': 'ABAP',
#    'repo': 'AES',
#    'repoLink': '/Sumu-Ning/AES',
#    'stars': 10,
#    'starsToday': 0},
#   {'author': 'HannesRempel',
#    'desc': 'Providing reusable ABAP components',
#    'forks': 1,
#    'lang': 'ABAP',
#    'repo': 'ABAP-Commons',
#    'repoLink': '/HannesRempel/ABAP-Commons',
#    'stars': 9,
#    'starsToday': 0},
#   {'author': 'RainerWinkler',
#    'desc': 'An project to extract model data from a SAP system with FAMIX and Moose',
#    'forks': 1,
#    'lang': 'ABAP',
#    'repo': 'Moose-FAMIX-SAP-Extractor',
#    'repoLink': '/RainerWinkler/Moose-FAMIX-SAP-Extractor',
#    'stars': 9,
#    'starsToday': 0},
#   {'author': 'koemaeda',
#    'desc': 'ABAP Markdown',
#    'forks': 1,
#    'lang': 'ABAP',
#    'repo': 'abap-markdown',
#    'repoLink': '/koemaeda/abap-markdown',
#    'stars': 9,
#    'starsToday': 0},
#   {'author': 'lucattelli',
#    'desc': 'Z Instant Comprehensive ABAP - Machine Learning Library',
#    'forks': 1,
#    'lang': 'ABAP',
#    'repo': 'ZICA_ML',
#    'repoLink': '/lucattelli/ZICA_ML',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'cesar-sap',
#    'desc': 'An ABAP class for sending DCN notifications to SUP (SAP/Sybase Unwired Platform)',
#    'forks': 1,
#    'lang': 'ABAP',
#    'repo': 'abap_sup_dcn',
#    'repoLink': '/cesar-sap/abap_sup_dcn',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'fatihpense',
#    'desc': 'Medepia ABAP JSON library that can generate and parse any JSON string.',
#    'forks': 3,
#    'lang': 'ABAP',
#    'repo': 'zcl_mdp_json',
#    'repoLink': '/fatihpense/zcl_mdp_json',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'larshp',
#    'desc': 'Git server implemented in ABAP',
#    'forks': 6,
#    'lang': 'ABAP',
#    'repo': 'abapGitServer',
#    'repoLink': '/larshp/abapGitServer',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'wwsheng009',
#    'desc': '',
#    'forks': 2,
#    'lang': 'ABAP',
#    'repo': 'ABAP',
#    'repoLink': '/wwsheng009/ABAP',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'abramsba',
#    'desc': 'ABAP command line interface utility',
#    'forks': 1,
#    'lang': 'ABAP',
#    'repo': 'abap-cli',
#    'repoLink': '/abramsba/abap-cli',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'lucattelli',
#    'desc': 'Z Instant Comprehensive ABAP example - Search Source',
#    'forks': 6,
#    'lang': 'ABAP',
#    'repo': 'ZICA_SEARCH_SOURCE',
#    'repoLink': '/lucattelli/ZICA_SEARCH_SOURCE',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'codecop',
#    'desc': 'Starting code for the Tennis Refactoring Kata in many programming languages used for Coding Dojo at ATD',
#    'forks': 236,
#    'lang': 'ABAP',
#    'repo': 'Tennis-Kata-ATD2013',
#    'repoLink': '/codecop/Tennis-Kata-ATD2013',
#    'stars': 6,
#    'starsToday': 0}],
#  'ABNF': [],
#  'AGS Script': [{'author': 'jeromeetienne',
#    'desc': 'extension system for three.js',
#    'forks': 111,
#    'lang': 'AGS Script',
#    'repo': 'tquery',
#    'repoLink': '/jeromeetienne/tquery',
#    'stars': 645,
#    'starsToday': 0},
#   {'author': 'KonradIT',
#    'desc': 'Autoexec hack is a copilation of hacks for GoPro Cameras, like a GHDK (GoPro Hack Developer Kit).',
#    'forks': 298,
#    'lang': 'AGS Script',
#    'repo': 'autoexechack',
#    'repoLink': '/KonradIT/autoexechack',
#    'stars': 329,
#    'starsToday': 0},
#   {'author': 'PJanisio',
#    'desc': 'Compilation of autoexec scripts and mods for Xiaomi Yi camera',
#    'forks': 26,
#    'lang': 'AGS Script',
#    'repo': 'Xiaomi_Yi_autoexec',
#    'repoLink': '/PJanisio/Xiaomi_Yi_autoexec',
#    'stars': 142,
#    'starsToday': 0},
#   {'author': 'funneld',
#    'desc': 'Collection of various improvements for XiaomiYi action camera',
#    'forks': 82,
#    'lang': 'AGS Script',
#    'repo': 'XiaomiYi',
#    'repoLink': '/funneld/XiaomiYi',
#    'stars': 113,
#    'starsToday': 0},
#   {'author': 'nairol',
#    'desc': 'Lighthouse Reverse-Engineered Documentation',
#    'forks': 13,
#    'lang': 'AGS Script',
#    'repo': 'LighthouseRedox',
#    'repoLink': '/nairol/LighthouseRedox',
#    'stars': 81,
#    'starsToday': 0},
#   {'author': 'asalga',
#    'desc': 'A WebGL library for streaming 3D point clouds',
#    'forks': 19,
#    'lang': 'AGS Script',
#    'repo': 'XB-PointStream',
#    'repoLink': '/asalga/XB-PointStream',
#    'stars': 61,
#    'starsToday': 0},
#   {'author': 'henjo',
#    'desc': 'Circuit analysis environment for Python',
#    'forks': 16,
#    'lang': 'AGS Script',
#    'repo': 'pycircuit',
#    'repoLink': '/henjo/pycircuit',
#    'stars': 47,
#    'starsToday': 0},
#   {'author': 'BlueBrain',
#    'desc': 'Neuronal Morphology Analysis Tool',
#    'forks': 13,
#    'lang': 'AGS Script',
#    'repo': 'NeuroM',
#    'repoLink': '/BlueBrain/NeuroM',
#    'stars': 20,
#    'starsToday': 0},
#   {'author': 'rapid7',
#    'desc': '',
#    'forks': 4,
#    'lang': 'AGS Script',
#    'repo': 'embedded-tools',
#    'repoLink': '/rapid7/embedded-tools',
#    'stars': 20,
#    'starsToday': 0},
#   {'author': 'cmars',
#    'desc': 'OpenPGP Key Server (main development is in github.com/hockeypuck/hockeypuck)',
#    'forks': 12,
#    'lang': 'AGS Script',
#    'repo': 'hockeypuck',
#    'repoLink': '/cmars/hockeypuck',
#    'stars': 19,
#    'starsToday': 0},
#   {'author': 'Bit-Nation',
#    'desc': 'Globally orientated citizenship with private passport services using available cryptographic tools',
#    'forks': 61,
#    'lang': 'AGS Script',
#    'repo': 'World-Citizenship',
#    'repoLink': '/Bit-Nation/World-Citizenship',
#    'stars': 19,
#    'starsToday': 0},
#   {'author': 'hypoxic',
#    'desc': 'Various GoPro HERO4 Session Scripts and information',
#    'forks': 4,
#    'lang': 'AGS Script',
#    'repo': 'hero4-session',
#    'repoLink': '/hypoxic/hero4-session',
#    'stars': 19,
#    'starsToday': 0},
#   {'author': 'roryk',
#    'desc': 'Diceware random password generation using the ANU quantum random number server as the randomness source',
#    'forks': 5,
#    'lang': 'AGS Script',
#    'repo': 'quantum-diceware',
#    'repoLink': '/roryk/quantum-diceware',
#    'stars': 18,
#    'starsToday': 0},
#   {'author': 'chrishwiggins',
#    'desc': 'little scripts to introduce people to each other.',
#    'forks': 3,
#    'lang': 'AGS Script',
#    'repo': 'orly',
#    'repoLink': '/chrishwiggins/orly',
#    'stars': 18,
#    'starsToday': 0},
#   {'author': 'hpimr',
#    'desc': 'Переклад українською hpmor.com. Згенерована html книжка тут: http://гпімр.укр/',
#    'forks': 8,
#    'lang': 'AGS Script',
#    'repo': 'hpimr',
#    'repoLink': '/hpimr/hpimr',
#    'stars': 17,
#    'starsToday': 0},
#   {'author': 'emanchado',
#    'desc': 'Libro "El camino a un mejor programador"',
#    'forks': 2,
#    'lang': 'AGS Script',
#    'repo': 'camino-mejor-programador',
#    'repoLink': '/emanchado/camino-mejor-programador',
#    'stars': 17,
#    'starsToday': 0},
#   {'author': 'arachnidlabs',
#    'desc': 'AVR based, arduino-compatible signal generator and frequency analyzer',
#    'forks': 4,
#    'lang': 'AGS Script',
#    'repo': 'tsunami',
#    'repoLink': '/arachnidlabs/tsunami',
#    'stars': 16,
#    'starsToday': 0},
#   {'author': 'hodefoting',
#    'desc': 'Tile/Component based font generator',
#    'forks': 1,
#    'lang': 'AGS Script',
#    'repo': '0xA000',
#    'repoLink': '/hodefoting/0xA000',
#    'stars': 14,
#    'starsToday': 0},
#   {'author': 'emsec',
#    'desc': 'Open tools for side-channel analysis and related techniques. Currently, this repository contains: 1) A near-field EM probe amplifier circuit',
#    'forks': 2,
#    'lang': 'AGS Script',
#    'repo': 'SCATools',
#    'repoLink': '/emsec/SCATools',
#    'stars': 14,
#    'starsToday': 0},
#   {'author': 'Ezandora',
#    'desc': 'Relay script for KoLmafia, for the web game Kingdom of Loathing. Gives advice on how to play.',
#    'forks': 3,
#    'lang': 'AGS Script',
#    'repo': 'Guide',
#    'repoLink': '/Ezandora/Guide',
#    'stars': 13,
#    'starsToday': 0},
#   {'author': 'gondur',
#    'desc': 'Cartlife Source code',
#    'forks': 2,
#    'lang': 'AGS Script',
#    'repo': 'cartlife_src',
#    'repoLink': '/gondur/cartlife_src',
#    'stars': 13,
#    'starsToday': 0},
#   {'author': 'FyberLabs',
#    'desc': 'Fyber Labs Flex Modules',
#    'forks': 12,
#    'lang': 'AGS Script',
#    'repo': 'FlexModule',
#    'repoLink': '/FyberLabs/FlexModule',
#    'stars': 12,
#    'starsToday': 0},
#   {'author': 'simeonf',
#    'desc': 'Sample code and slides for an SQL Alchemy ORM tutorial',
#    'forks': 5,
#    'lang': 'AGS Script',
#    'repo': 'sqlalchemy-tutorial',
#    'repoLink': '/simeonf/sqlalchemy-tutorial',
#    'stars': 12,
#    'starsToday': 0},
#   {'author': 'OpenSourceBrain',
#    'desc': 'A project to illustrate how models and data from the Blue Brain Project can be converted to NeuroML and PyNN',
#    'forks': 11,
#    'lang': 'AGS Script',
#    'repo': 'BlueBrainProjectShowcase',
#    'repoLink': '/OpenSourceBrain/BlueBrainProjectShowcase',
#    'stars': 11,
#    'starsToday': 0},
#   {'author': 'myriadrf',
#    'desc': 'MIMO platform for advanced communications and PNT applications',
#    'forks': 9,
#    'lang': 'AGS Script',
#    'repo': 'A2300',
#    'repoLink': '/myriadrf/A2300',
#    'stars': 11,
#    'starsToday': 0}],
#  'AMPL': [{'author': 'amusecode',
#    'desc': 'Astrophysical Multipurpose Software Environment. This is the main repository for AMUSE',
#    'forks': 23,
#    'lang': 'AMPL',
#    'repo': 'amuse',
#    'repoLink': '/amusecode/amuse',
#    'stars': 29,
#    'starsToday': 0},
#   {'author': 'congdm',
#    'desc': 'An Oberon-07 compiler for Intel 64 (AMD64) architecture',
#    'forks': 3,
#    'lang': 'AMPL',
#    'repo': 'Patchouli-Compiler',
#    'repoLink': '/congdm/Patchouli-Compiler',
#    'stars': 24,
#    'starsToday': 0},
#   {'author': 'JohannesPfeifer',
#    'desc': 'A collection of Dynare models',
#    'forks': 20,
#    'lang': 'AMPL',
#    'repo': 'DSGE_mod',
#    'repoLink': '/JohannesPfeifer/DSGE_mod',
#    'stars': 15,
#    'starsToday': 0},
#   {'author': 'Chadderz121',
#    'desc': 'CT-CODE Mario Kart Wii mod',
#    'forks': 7,
#    'lang': 'AMPL',
#    'repo': 'wii-ct-code',
#    'repoLink': '/Chadderz121/wii-ct-code',
#    'stars': 13,
#    'starsToday': 0},
#   {'author': 'mlubin',
#    'desc': 'Repository containing supplementary materials and code for "JuMP: A Modeling Language for Mathematical Optimization"',
#    'forks': 1,
#    'lang': 'AMPL',
#    'repo': 'JuMPSupplement',
#    'repoLink': '/mlubin/JuMPSupplement',
#    'stars': 10,
#    'starsToday': 0},
#   {'author': 'nasa',
#    'desc': '',
#    'forks': 9,
#    'lang': 'AMPL',
#    'repo': 'WinSURE',
#    'repoLink': '/nasa/WinSURE',
#    'stars': 9,
#    'starsToday': 0},
#   {'author': 'klo-manolo',
#    'desc': 'Basic features for eneboo modules',
#    'forks': 14,
#    'lang': 'AMPL',
#    'repo': 'eneboo-features',
#    'repoLink': '/klo-manolo/eneboo-features',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'xirsoi',
#    'desc': 'Ancient Religions mod for CK2',
#    'forks': 13,
#    'lang': 'AMPL',
#    'repo': 'ancientreligions',
#    'repoLink': '/xirsoi/ancientreligions',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'ampl',
#    'desc': 'Global optimization test set',
#    'forks': 2,
#    'lang': 'AMPL',
#    'repo': 'global-optimization',
#    'repoLink': '/ampl/global-optimization',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'mpf',
#    'desc': '',
#    'forks': 5,
#    'lang': 'AMPL',
#    'repo': 'Optimization-Test-Problems',
#    'repoLink': '/mpf/Optimization-Test-Problems',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'esa',
#    'desc': 'AMPL transcriptions of optimal control problems of space relevance (requires ampl commercial software)',
#    'forks': 1,
#    'lang': 'AMPL',
#    'repo': 'SpaceAMPL',
#    'repoLink': '/esa/SpaceAMPL',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'KaliLab',
#    'desc': 'Optimization of neuronal models',
#    'forks': 9,
#    'lang': 'AMPL',
#    'repo': 'optimizer',
#    'repoLink': '/KaliLab/optimizer',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'nasa',
#    'desc': '',
#    'forks': 5,
#    'lang': 'AMPL',
#    'repo': 'WinASSIST',
#    'repoLink': '/nasa/WinASSIST',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'marekyggdrasil',
#    'desc': '',
#    'forks': 0,
#    'lang': 'AMPL',
#    'repo': 'optilogistics',
#    'repoLink': '/marekyggdrasil/optilogistics',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'CoFH',
#    'desc': 'Repository for Stellar Expansion and all related addons!',
#    'forks': 2,
#    'lang': 'AMPL',
#    'repo': 'StellarExpansion',
#    'repoLink': '/CoFH/StellarExpansion',
#    'stars': 5,
#    'starsToday': 0},
#   {'author': 'm00nnsplit',
#    'desc': 'Mod for Europa Universalis IV that adds My Little Pony stuff in Northern America.',
#    'forks': 6,
#    'lang': 'AMPL',
#    'repo': 'EU4-equestria-mod',
#    'repoLink': '/m00nnsplit/EU4-equestria-mod',
#    'stars': 5,
#    'starsToday': 0},
#   {'author': 'pavn',
#    'desc': 'Convex Optimization models with exact and heuristic solution procedures',
#    'forks': 0,
#    'lang': 'AMPL',
#    'repo': 'IndustrialMathProgramming',
#    'repoLink': '/pavn/IndustrialMathProgramming',
#    'stars': 5,
#    'starsToday': 0},
#   {'author': 'rieder',
#    'desc': 'Astrophysical Multipurpose Software Environment. This is my fork of the main repository for AMUSE.',
#    'forks': 23,
#    'lang': 'AMPL',
#    'repo': 'amuse',
#    'repoLink': '/rieder/amuse',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'proofcert',
#    'desc': '',
#    'forks': 1,
#    'lang': 'AMPL',
#    'repo': 'fpccheck',
#    'repoLink': '/proofcert/fpccheck',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'Wiimm',
#    'desc': 'CT-CODE Mario Kart Wii mod',
#    'forks': 7,
#    'lang': 'AMPL',
#    'repo': 'wii-ct-code',
#    'repoLink': '/Wiimm/wii-ct-code',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'LittleSchnitz',
#    'desc': '',
#    'forks': 1,
#    'lang': 'AMPL',
#    'repo': 'kubaluba',
#    'repoLink': '/LittleSchnitz/kubaluba',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'adamnie',
#    'desc': '',
#    'forks': 1,
#    'lang': 'AMPL',
#    'repo': 'MwPSiS_solutions',
#    'repoLink': '/adamnie/MwPSiS_solutions',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'compneuro',
#    'desc': 'Simulation scripts to compute Local Field Potentials (LFP) of cable compartmental models implemented with NEURON',
#    'forks': 2,
#    'lang': 'AMPL',
#    'repo': 'LFPsim',
#    'repoLink': '/compneuro/LFPsim',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'ronkeizer',
#    'desc': '',
#    'forks': 2,
#    'lang': 'AMPL',
#    'repo': 'nonmem_examples',
#    'repoLink': '/ronkeizer/nonmem_examples',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'lucky13pjn',
#    'desc': "Omicron's Cheats mod for EUIV",
#    'forks': 0,
#    'lang': 'AMPL',
#    'repo': 'OmicronsCheats',
#    'repoLink': '/lucky13pjn/OmicronsCheats',
#    'stars': 3,
#    'starsToday': 0}],
#  'ANTLR': [{'author': 'antlr',
#    'desc': 'Grammars written for ANTLR v4; expectation that the grammars are free of actions.',
#    'forks': 642,
#    'lang': 'ANTLR',
#    'repo': 'grammars-v4',
#    'repoLink': '/antlr/grammars-v4',
#    'stars': 1476,
#    'starsToday': 0},
#   {'author': 'polysome',
#    'desc': 'An open source miniPCIe development board based on the Xilinx Spartan 6 LX150T',
#    'forks': 7,
#    'lang': 'ANTLR',
#    'repo': 'aggregate-1',
#    'repoLink': '/polysome/aggregate-1',
#    'stars': 118,
#    'starsToday': 0},
#   {'author': 'myriadrf',
#    'desc': 'USB 3.0 version of the LimeSDR board',
#    'forks': 29,
#    'lang': 'ANTLR',
#    'repo': 'LimeSDR-USB',
#    'repoLink': '/myriadrf/LimeSDR-USB',
#    'stars': 90,
#    'starsToday': 0},
#   {'author': '3drobotics',
#    'desc': 'Design files for the open hardware designs used by 3DR',
#    'forks': 49,
#    'lang': 'ANTLR',
#    'repo': 'Pixhawk_OS_Hardware',
#    'repoLink': '/3drobotics/Pixhawk_OS_Hardware',
#    'stars': 44,
#    'starsToday': 0},
#   {'author': 'bkiers',
#    'desc': 'Railroad Diagrams for ANTLR 4 grammar rules.',
#    'forks': 8,
#    'lang': 'ANTLR',
#    'repo': 'rrd-antlr4',
#    'repoLink': '/bkiers/rrd-antlr4',
#    'stars': 36,
#    'starsToday': 0},
#   {'author': 'brettwooldridge',
#    'desc': 'Swift-to-JVM bytecode compiler.',
#    'forks': 1,
#    'lang': 'ANTLR',
#    'repo': 'jet',
#    'repoLink': '/brettwooldridge/jet',
#    'stars': 33,
#    'starsToday': 0},
#   {'author': 'jbclements',
#    'desc': 'An ANTLR grammar for Rust',
#    'forks': 6,
#    'lang': 'ANTLR',
#    'repo': 'rust-antlr',
#    'repoLink': '/jbclements/rust-antlr',
#    'stars': 29,
#    'starsToday': 0},
#   {'author': 'fenollp',
#    'desc': 'er ~ emergency room (a BEAM language "improving" on Erlang)',
#    'forks': 3,
#    'lang': 'ANTLR',
#    'repo': 'er',
#    'repoLink': '/fenollp/er',
#    'stars': 24,
#    'starsToday': 0},
#   {'author': 'tunnelvisionlabs',
#    'desc': 'An ANTLR 4 lexer for PostgreSQL',
#    'forks': 9,
#    'lang': 'ANTLR',
#    'repo': 'antlr4-grammar-postgresql',
#    'repoLink': '/tunnelvisionlabs/antlr4-grammar-postgresql',
#    'stars': 14,
#    'starsToday': 0},
#   {'author': 'AnttiLukats',
#    'desc': '',
#    'forks': 8,
#    'lang': 'ANTLR',
#    'repo': 'Soft-Propeller',
#    'repoLink': '/AnttiLukats/Soft-Propeller',
#    'stars': 13,
#    'starsToday': 0},
#   {'author': 'cyberthinkers',
#    'desc': 'This tool will create JavaScript facades for Scala.js from typescript ambient declarations.',
#    'forks': 0,
#    'lang': 'ANTLR',
#    'repo': 'typescript-to-scala-js-facade',
#    'repoLink': '/cyberthinkers/typescript-to-scala-js-facade',
#    'stars': 13,
#    'starsToday': 0},
#   {'author': 'drforr',
#    'desc': 'Parser for ANTLR4 grammar',
#    'forks': 6,
#    'lang': 'ANTLR',
#    'repo': 'perl6-ANTLR4',
#    'repoLink': '/drforr/perl6-ANTLR4',
#    'stars': 12,
#    'starsToday': 0},
#   {'author': 'AnttiLukats',
#    'desc': 'Open Source ZYNQ Board',
#    'forks': 8,
#    'lang': 'ANTLR',
#    'repo': 'HackaZynq',
#    'repoLink': '/AnttiLukats/HackaZynq',
#    'stars': 12,
#    'starsToday': 0},
#   {'author': 'ftomassetti',
#    'desc': 'Python parser built using ANTLR',
#    'forks': 2,
#    'lang': 'ANTLR',
#    'repo': 'python-ast',
#    'repoLink': '/ftomassetti/python-ast',
#    'stars': 12,
#    'starsToday': 0},
#   {'author': 'bkiers',
#    'desc': 'An ANTLR 4 grammar for PCRE',
#    'forks': 0,
#    'lang': 'ANTLR',
#    'repo': 'pcre-parser',
#    'repoLink': '/bkiers/pcre-parser',
#    'stars': 11,
#    'starsToday': 0},
#   {'author': 'SpaceKrakens',
#    'desc': 'Space Kraken Object Notation',
#    'forks': 7,
#    'lang': 'ANTLR',
#    'repo': 'SKON',
#    'repoLink': '/SpaceKrakens/SKON',
#    'stars': 10,
#    'starsToday': 0},
#   {'author': 'le-moulin-studio',
#    'desc': 'Experiment about a semantic-based diff tool for Java language.',
#    'forks': 1,
#    'lang': 'ANTLR',
#    'repo': 'java-semantic-diff',
#    'repoLink': '/le-moulin-studio/java-semantic-diff',
#    'stars': 10,
#    'starsToday': 0},
#   {'author': 'ftomassetti',
#    'desc': 'A complement to ANTLR to get a model from your AST and transform it',
#    'forks': 0,
#    'lang': 'ANTLR',
#    'repo': 'antlr-plus',
#    'repoLink': '/ftomassetti/antlr-plus',
#    'stars': 9,
#    'starsToday': 0},
#   {'author': 'lrlucena',
#    'desc': 'Grammars written for ANTLR v4; expectation that the grammars are free of actions.',
#    'forks': 642,
#    'lang': 'ANTLR',
#    'repo': 'grammars-v4',
#    'repoLink': '/lrlucena/grammars-v4',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'AnttiLukats',
#    'desc': 'Open Hardware Zynq System on Module',
#    'forks': 5,
#    'lang': 'ANTLR',
#    'repo': 'OZOM-Model-A',
#    'repoLink': '/AnttiLukats/OZOM-Model-A',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'cy6erGn0m',
#    'desc': 'Antlr4 grammar for Kotlin language',
#    'forks': 0,
#    'lang': 'ANTLR',
#    'repo': 'kotlin-antlr4-grammar',
#    'repoLink': '/cy6erGn0m/kotlin-antlr4-grammar',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'proficnc',
#    'desc': 'Generic hardware designs',
#    'forks': 4,
#    'lang': 'ANTLR',
#    'repo': 'ProfiCNC_Hardware',
#    'repoLink': '/proficnc/ProfiCNC_Hardware',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'vlsi',
#    'desc': 'Parsers for IEC 61131-3 grammar',
#    'forks': 0,
#    'lang': 'ANTLR',
#    'repo': 'iec61131-parser',
#    'repoLink': '/vlsi/iec61131-parser',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'nightscape',
#    'desc': 'Use ANTLR4 grammars for creating incremental Papa Carlo parsers',
#    'forks': 0,
#    'lang': 'ANTLR',
#    'repo': 'papa-carlos-aunt',
#    'repoLink': '/nightscape/papa-carlos-aunt',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'myriadrf',
#    'desc': '',
#    'forks': 3,
#    'lang': 'ANTLR',
#    'repo': 'LimeSDR-PCIe',
#    'repoLink': '/myriadrf/LimeSDR-PCIe',
#    'stars': 4,
#    'starsToday': 0}],
#  'API Blueprint': [{'author': 'cloudapp',
#    'desc': 'The CloudApp API',
#    'forks': 38,
#    'lang': 'API Blueprint',
#    'repo': 'api',
#    'repoLink': '/cloudapp/api',
#    'stars': 135,
#    'starsToday': 0},
#   {'author': 'buildasaurs',
#    'desc': 'Unofficial documentation of the Xcode Server API (Xcode 7 edition)',
#    'forks': 4,
#    'lang': 'API Blueprint',
#    'repo': 'XcodeServer-API-Docs',
#    'repoLink': '/buildasaurs/XcodeServer-API-Docs',
#    'stars': 58,
#    'starsToday': 0},
#   {'author': 'the-grid',
#    'desc': 'API documentation for The Grid',
#    'forks': 10,
#    'lang': 'API Blueprint',
#    'repo': 'apidocs',
#    'repoLink': '/the-grid/apidocs',
#    'stars': 42,
#    'starsToday': 0},
#   {'author': 'gooddata',
#    'desc': 'GoodData API documentation',
#    'forks': 45,
#    'lang': 'API Blueprint',
#    'repo': 'gooddata-api-docs',
#    'repoLink': '/gooddata/gooddata-api-docs',
#    'stars': 28,
#    'starsToday': 0},
#   {'author': 'jsynowiec',
#    'desc': 'Minimalistic boilerplate to quick-start API specification using API Blueprint description language.',
#    'forks': 4,
#    'lang': 'API Blueprint',
#    'repo': 'api-blueprint-boilerplate',
#    'repoLink': '/jsynowiec/api-blueprint-boilerplate',
#    'stars': 25,
#    'starsToday': 0},
#   {'author': 'ipfs',
#    'desc': 'Apiary IPFS HTTP API description',
#    'forks': 11,
#    'lang': 'API Blueprint',
#    'repo': 'http-api-spec',
#    'repoLink': '/ipfs/http-api-spec',
#    'stars': 24,
#    'starsToday': 0},
#   {'author': 'fakturoid',
#    'desc': 'API documentation for Fakturoid',
#    'forks': 5,
#    'lang': 'API Blueprint',
#    'repo': 'api',
#    'repoLink': '/fakturoid/api',
#    'stars': 23,
#    'starsToday': 0},
#   {'author': 'saamo',
#    'desc': 'Gulp tasks for writing large API Blueprints efficiently',
#    'forks': 4,
#    'lang': 'API Blueprint',
#    'repo': 'api-blueprint-focus-booster',
#    'repoLink': '/saamo/api-blueprint-focus-booster',
#    'stars': 22,
#    'starsToday': 0},
#   {'author': 'ging',
#    'desc': 'Identity Manager - Keyrock',
#    'forks': 17,
#    'lang': 'API Blueprint',
#    'repo': 'fiware-idm',
#    'repoLink': '/ging/fiware-idm',
#    'stars': 20,
#    'starsToday': 0},
#   {'author': 'hoodiehq',
#    'desc': 'REST-API Blueprint for all things user accounts and sesions',
#    'forks': 11,
#    'lang': 'API Blueprint',
#    'repo': 'account-json-api',
#    'repoLink': '/hoodiehq/account-json-api',
#    'stars': 19,
#    'starsToday': 0},
#   {'author': 'scaleway',
#    'desc': '📝 Scaleway API documentation',
#    'forks': 6,
#    'lang': 'API Blueprint',
#    'repo': 'api.scaleway.com',
#    'repoLink': '/scaleway/api.scaleway.com',
#    'stars': 19,
#    'starsToday': 0},
#   {'author': 'ascribe',
#    'desc': 'Main RESTful API for ascribe ownership web service.',
#    'forks': 13,
#    'lang': 'API Blueprint',
#    'repo': 'REST-main',
#    'repoLink': '/ascribe/REST-main',
#    'stars': 18,
#    'starsToday': 0},
#   {'author': 'contentful',
#    'desc': 'Contentful Developer center content',
#    'forks': 10,
#    'lang': 'API Blueprint',
#    'repo': 'slash-developers',
#    'repoLink': '/contentful/slash-developers',
#    'stars': 15,
#    'starsToday': 0},
#   {'author': 'MeteoGroup',
#    'desc': "MeteoGroup's public weather API documentation",
#    'forks': 3,
#    'lang': 'API Blueprint',
#    'repo': 'weather-api',
#    'repoLink': '/MeteoGroup/weather-api',
#    'stars': 14,
#    'starsToday': 0},
#   {'author': 'plantbreeding',
#    'desc': 'Community documentation for the Plant Breeding group',
#    'forks': 1,
#    'lang': 'API Blueprint',
#    'repo': 'Documentation',
#    'repoLink': '/plantbreeding/Documentation',
#    'stars': 11,
#    'starsToday': 0},
#   {'author': 'philipbrown',
#    'desc': 'A complete workflow for converting API Blueprint to hosted documentation on S3',
#    'forks': 1,
#    'lang': 'API Blueprint',
#    'repo': 'api-blueprint-s3',
#    'repoLink': '/philipbrown/api-blueprint-s3',
#    'stars': 11,
#    'starsToday': 0},
#   {'author': 'silsha',
#    'desc': 'Documentation of the RNV (Rhein-Neckar Verkehr) api',
#    'forks': 2,
#    'lang': 'API Blueprint',
#    'repo': 'rnv-api',
#    'repoLink': '/silsha/rnv-api',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'RekolaCZ',
#    'desc': '',
#    'forks': 2,
#    'lang': 'API Blueprint',
#    'repo': 'mobile-api',
#    'repoLink': '/RekolaCZ/mobile-api',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'nicupavel',
#    'desc': 'RainMachine RESTful API (version 4)',
#    'forks': 7,
#    'lang': 'API Blueprint',
#    'repo': 'rainmachine-api',
#    'repoLink': '/nicupavel/rainmachine-api',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'HiTask',
#    'desc': 'API documentation for HiTask',
#    'forks': 2,
#    'lang': 'API Blueprint',
#    'repo': 'api',
#    'repoLink': '/HiTask/api',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'greensea',
#    'desc': 'Youxia Motors User API',
#    'forks': 3,
#    'lang': 'API Blueprint',
#    'repo': 'youxiaapi',
#    'repoLink': '/greensea/youxiaapi',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'PerformanceHorizonGroup',
#    'desc': 'Docs for the public PH API',
#    'forks': 7,
#    'lang': 'API Blueprint',
#    'repo': 'apidocs',
#    'repoLink': '/PerformanceHorizonGroup/apidocs',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'MichielDeMey',
#    'desc': '🚍 RESTful API documentation for De Lijn',
#    'forks': 2,
#    'lang': 'API Blueprint',
#    'repo': 'delijn-api',
#    'repoLink': '/MichielDeMey/delijn-api',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'open-falcon',
#    'desc': 'OpenFalcon API doc',
#    'forks': 5,
#    'lang': 'API Blueprint',
#    'repo': 'apidoc',
#    'repoLink': '/open-falcon/apidoc',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'initialstate',
#    'desc': 'Documentation for consuming the Initial State events api',
#    'forks': 7,
#    'lang': 'API Blueprint',
#    'repo': 'public-api-docs',
#    'repoLink': '/initialstate/public-api-docs',
#    'stars': 5,
#    'starsToday': 0}],
#  'APL': [{'author': 'arcfide',
#    'desc': 'High-performance, Reliable, and Parallel APL',
#    'forks': 9,
#    'lang': 'APL',
#    'repo': 'Co-dfns',
#    'repoLink': '/arcfide/Co-dfns',
#    'stars': 99,
#    'starsToday': 0},
#   {'author': 'Dyalog',
#    'desc': 'A simple "columnar database" based on memory-mapped files, written in APL',
#    'forks': 1,
#    'lang': 'APL',
#    'repo': 'vecdb',
#    'repoLink': '/Dyalog/vecdb',
#    'stars': 11,
#    'starsToday': 0},
#   {'author': 'mattcunningham',
#    'desc': 'Naive Bayesian Classifier written in APL',
#    'forks': 1,
#    'lang': 'APL',
#    'repo': 'naive-apl',
#    'repoLink': '/mattcunningham/naive-apl',
#    'stars': 9,
#    'starsToday': 0},
#   {'author': 'blakemcbride',
#    'desc': 'APL function editor written in APL',
#    'forks': 2,
#    'lang': 'APL',
#    'repo': 'APLEditor',
#    'repoLink': '/blakemcbride/APLEditor',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'Dyalog',
#    'desc': "Brian Becker's Amazing Amalgam of APL",
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'bb',
#    'repoLink': '/Dyalog/bb',
#    'stars': 5,
#    'starsToday': 0},
#   {'author': 'flouc001',
#    'desc': 'A simple APL neural network.',
#    'forks': 2,
#    'lang': 'APL',
#    'repo': 'Simple-APL-Neural',
#    'repoLink': '/flouc001/Simple-APL-Neural',
#    'stars': 5,
#    'starsToday': 0},
#   {'author': 'TieDyedDevil',
#    'desc': 'APL package manager',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'apl-pkg',
#    'repoLink': '/TieDyedDevil/apl-pkg',
#    'stars': 5,
#    'starsToday': 0},
#   {'author': '5jt',
#    'desc': 'Book and code: how to build and distribute applications in Dyalog APL',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'dyalog-cookbook',
#    'repoLink': '/5jt/dyalog-cookbook',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'annser',
#    'desc': 'ANNSER is A Neural Network Simulator for Education and Research.',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'annser',
#    'repoLink': '/annser/annser',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'Gianfrancoalongi',
#    'desc': 'APLUnit - a library to facilitate Unit Testing and Test Driven Development of code written in Dyalog APL, developed together with Morten Kromberg (CTO Dyalog Ltd)',
#    'forks': 2,
#    'lang': 'APL',
#    'repo': 'APLUnit',
#    'repoLink': '/Gianfrancoalongi/APLUnit',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'Dyalog',
#    'desc': 'Collection of MiSites for use with MiServer',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'MiSites',
#    'repoLink': '/Dyalog/MiSites',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'blakemcbride',
#    'desc': 'APL utilities for business applications',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'APLUtils',
#    'repoLink': '/blakemcbride/APLUtils',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'alexcweiner',
#    'desc': 'Utility functions to get images in and out of (GNU) APL',
#    'forks': 1,
#    'lang': 'APL',
#    'repo': 'APL-Image-Utilities',
#    'repoLink': '/alexcweiner/APL-Image-Utilities',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'ValeryAnisimovsky',
#    'desc': 'Game Audio Player',
#    'forks': 3,
#    'lang': 'APL',
#    'repo': 'GameAudioPlayer',
#    'repoLink': '/ValeryAnisimovsky/GameAudioPlayer',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'theaplroom',
#    'desc': '',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'apl-sound-wave',
#    'repoLink': '/theaplroom/apl-sound-wave',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'arcfide',
#    'desc': 'Farbfeld Dictionary',
#    'forks': 1,
#    'lang': 'APL',
#    'repo': 'ffdict',
#    'repoLink': '/arcfide/ffdict',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'OptimaSystems',
#    'desc': 'Granular APL Project manager. For easy management of source code in external files.',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'GAP',
#    'repoLink': '/OptimaSystems/GAP',
#    'stars': 2,
#    'starsToday': 0},
#   {'author': 'plj541',
#    'desc': 'Contains additional Workspaces and Files.',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'APL.js.User',
#    'repoLink': '/plj541/APL.js.User',
#    'stars': 2,
#    'starsToday': 0},
#   {'author': 'nholland94',
#    'desc': 'A 2D tile based dungeon generator written in APL',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'apl-dungeon-generator',
#    'repoLink': '/nholland94/apl-dungeon-generator',
#    'stars': 2,
#    'starsToday': 0},
#   {'author': 'laynor',
#    'desc': 'Exercises from http://aplwiki.com/LearnApl/LearningApl',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'learn-apl',
#    'repoLink': '/laynor/learn-apl',
#    'stars': 2,
#    'starsToday': 0},
#   {'author': 'ngn',
#    'desc': 'experiment: a font generated by an APL script',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'font',
#    'repoLink': '/ngn/font',
#    'stars': 2,
#    'starsToday': 0},
#   {'author': 'taptap',
#    'desc': 'ugh',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'apl-fun',
#    'repoLink': '/taptap/apl-fun',
#    'stars': 2,
#    'starsToday': 0},
#   {'author': 'StoneCypher',
#    'desc': 'Deepak Chopra nonsense phrase generator implementation in APL. *Lol*.',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'DeepakChopra_APL',
#    'repoLink': '/StoneCypher/DeepakChopra_APL',
#    'stars': 2,
#    'starsToday': 0},
#   {'author': 'blakemcbride',
#    'desc': 'Component File System for GNU APL',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'APLComponentFiles',
#    'repoLink': '/blakemcbride/APLComponentFiles',
#    'stars': 2,
#    'starsToday': 0},
#   {'author': 'theaplroom',
#    'desc': 'A script that builds a form and allows you to apply filters on images.',
#    'forks': 0,
#    'lang': 'APL',
#    'repo': 'APL-Image-Filters',
#    'repoLink': '/theaplroom/APL-Image-Filters',
#    'stars': 2,
#    'starsToday': 0}],
#  'ASN.1': [],
#  'ASP': [{'author': 'koolshare',
#    'desc': 'For koolshare.cn',
#    'forks': 227,
#    'lang': 'ASP',
#    'repo': 'koolshare.github.io',
#    'repoLink': '/koolshare/koolshare.github.io',
#    'stars': 533,
#    'starsToday': 0},
#   {'author': 'SharePoint',
#    'desc': 'SharePoint Developer Documentation',
#    'forks': 100,
#    'lang': 'ASP',
#    'repo': 'sp-dev-docs',
#    'repoLink': '/SharePoint/sp-dev-docs',
#    'stars': 324,
#    'starsToday': 0},
#   {'author': 'oazabir',
#    'desc': 'A web-based real-time monitoring app to show performance and problems of one or more SQL Server instances',
#    'forks': 34,
#    'lang': 'ASP',
#    'repo': 'SQLServerPerformanceDashboard',
#    'repoLink': '/oazabir/SQLServerPerformanceDashboard',
#    'stars': 90,
#    'starsToday': 0},
#   {'author': 'zendesk',
#    'desc': 'Examples using JWT for Zendesk SSO',
#    'forks': 45,
#    'lang': 'ASP',
#    'repo': 'zendesk_jwt_sso_examples',
#    'repoLink': '/zendesk/zendesk_jwt_sso_examples',
#    'stars': 82,
#    'starsToday': 0},
#   {'author': 'Jackysi',
#    'desc': 'This is GUI only version of repository (www directory)',
#    'forks': 35,
#    'lang': 'ASP',
#    'repo': 'advancedtomato-gui',
#    'repoLink': '/Jackysi/advancedtomato-gui',
#    'stars': 76,
#    'starsToday': 0},
#   {'author': 'lowleveldesign',
#    'desc': 'My notes collected while debugging various .NET and Windows problems.',
#    'forks': 16,
#    'lang': 'ASP',
#    'repo': 'debug-recipes',
#    'repoLink': '/lowleveldesign/debug-recipes',
#    'stars': 71,
#    'starsToday': 0},
#   {'author': 'golanlevin',
#    'desc': 'A Curriculum for a Semester Course in Computational & Expanded ███ography',
#    'forks': 37,
#    'lang': 'ASP',
#    'repo': 'ExperimentalCapture',
#    'repoLink': '/golanlevin/ExperimentalCapture',
#    'stars': 64,
#    'starsToday': 0},
#   {'author': 'coldstone',
#    'desc': 'A simple classic ASP (VBScript) library with database control, FSO, upload, JSON creator & parser, XML creator, template engine...',
#    'forks': 29,
#    'lang': 'ASP',
#    'repo': 'easyasp',
#    'repoLink': '/coldstone/easyasp',
#    'stars': 57,
#    'starsToday': 0},
#   {'author': 'purtuga',
#    'desc': 'Sharepoint Custom UI Widgets',
#    'forks': 23,
#    'lang': 'ASP',
#    'repo': 'SPWidgets',
#    'repoLink': '/purtuga/SPWidgets',
#    'stars': 56,
#    'starsToday': 0},
#   {'author': 'david-mark',
#    'desc': 'The original cross-browser JS library/framework',
#    'forks': 13,
#    'lang': 'ASP',
#    'repo': 'My-Library',
#    'repoLink': '/david-mark/My-Library',
#    'stars': 55,
#    'starsToday': 0},
#   {'author': 'rcdmk',
#    'desc': 'A fast classic ASP JSON parser and encoder for easy JSON manipulation to work with the new JavaScript MV* libraries and frameworks.',
#    'forks': 24,
#    'lang': 'ASP',
#    'repo': 'aspJSON',
#    'repoLink': '/rcdmk/aspJSON',
#    'stars': 52,
#    'starsToday': 0},
#   {'author': 'OpenAgInitiative',
#    'desc': '**ALPHA VERSION** Code for the user interface application',
#    'forks': 13,
#    'lang': 'ASP',
#    'repo': 'gro-ui',
#    'repoLink': '/OpenAgInitiative/gro-ui',
#    'stars': 47,
#    'starsToday': 0},
#   {'author': 'DynamsoftRD',
#    'desc': 'Take a Photo and Upload it on Mobile Phones with HTML5',
#    'forks': 24,
#    'lang': 'ASP',
#    'repo': 'HTML5-Photo-Upload',
#    'repoLink': '/DynamsoftRD/HTML5-Photo-Upload',
#    'stars': 40,
#    'starsToday': 0},
#   {'author': 'sdesapio',
#    'desc': 'Generic VBScript class structure for implementing OAUTH.',
#    'forks': 22,
#    'lang': 'ASP',
#    'repo': 'Classic-ASP-VBScript-OAuth',
#    'repoLink': '/sdesapio/Classic-ASP-VBScript-OAuth',
#    'stars': 38,
#    'starsToday': 0},
#   {'author': 'PentestHub',
#    'desc': '提权的文档',
#    'forks': 15,
#    'lang': 'ASP',
#    'repo': 'PriviledgeBook',
#    'repoLink': '/PentestHub/PriviledgeBook',
#    'stars': 37,
#    'starsToday': 0},
#   {'author': 'merttasci',
#    'desc': '🔪 This repo contains required files for web application pentest.',
#    'forks': 11,
#    'lang': 'ASP',
#    'repo': 'weapons4pentester',
#    'repoLink': '/merttasci/weapons4pentester',
#    'stars': 36,
#    'starsToday': 0},
#   {'author': 'SteveSanderson',
#    'desc': 'Cross-process code injection for ASP.NET',
#    'forks': 12,
#    'lang': 'ASP',
#    'repo': 'Deleporter',
#    'repoLink': '/SteveSanderson/Deleporter',
#    'stars': 36,
#    'starsToday': 0},
#   {'author': 'ChrisHammond',
#    'desc': 'Another free open source skin for DNN (DotNetNuke) using Bootstrap 3 grab the latest release from the RELEASES tab. https://github.com/ChrisHammond/HammerFlex/releases',
#    'forks': 24,
#    'lang': 'ASP',
#    'repo': 'HammerFlex',
#    'repoLink': '/ChrisHammond/HammerFlex',
#    'stars': 28,
#    'starsToday': 0},
#   {'author': 'Dheer-Rajpoot',
#    'desc': 'This repository contains code and files related to ASP.NET',
#    'forks': 79,
#    'lang': 'ASP',
#    'repo': 'ASP.NET',
#    'repoLink': '/Dheer-Rajpoot/ASP.NET',
#    'stars': 28,
#    'starsToday': 0},
#   {'author': 'NetSPI',
#    'desc': '',
#    'forks': 8,
#    'lang': 'ASP',
#    'repo': 'cmdsql',
#    'repoLink': '/NetSPI/cmdsql',
#    'stars': 28,
#    'starsToday': 0},
#   {'author': 'zblogcn',
#    'desc': 'Z-Blog是一款小巧而强大的ASP博客程序，同时支持Microsoft Access和Microsoft SQL Server两种数据库。',
#    'forks': 16,
#    'lang': 'ASP',
#    'repo': 'zblogasp',
#    'repoLink': '/zblogcn/zblogasp',
#    'stars': 27,
#    'starsToday': 0},
#   {'author': 'anderssonjohan',
#    'desc': 'Internet bandwidth test written in HTML+AJAX using jQuery',
#    'forks': 8,
#    'lang': 'ASP',
#    'repo': 'Nettest',
#    'repoLink': '/anderssonjohan/Nettest',
#    'stars': 26,
#    'starsToday': 0},
#   {'author': 'hrbrmstr',
#    'desc': 'Slides/code/data from rstudio:: conf 2017',
#    'forks': 1,
#    'lang': 'ASP',
#    'repo': 'rstudioconf2017',
#    'repoLink': '/hrbrmstr/rstudioconf2017',
#    'stars': 25,
#    'starsToday': 0},
#   {'author': 'tutsplus',
#    'desc': 'How to Generate Shockingly Good 2D Lightning Effects in Unity',
#    'forks': 15,
#    'lang': 'ASP',
#    'repo': 'shockingly-good-2d-lightning-effects-unity',
#    'repoLink': '/tutsplus/shockingly-good-2d-lightning-effects-unity',
#    'stars': 23,
#    'starsToday': 0},
#   {'author': 'tshwangq',
#    'desc': 'delopy asp.net website with github automatically',
#    'forks': 13,
#    'lang': 'ASP',
#    'repo': 'IISDeploy',
#    'repoLink': '/tshwangq/IISDeploy',
#    'stars': 23,
#    'starsToday': 0}],
#  'ATS': [{'author': 'githwxi',
#    'desc': 'ATS2: Unleashing the Potentials of Types and Templates',
#    'forks': 29,
#    'lang': 'ATS',
#    'repo': 'ATS-Postiats',
#    'repoLink': '/githwxi/ATS-Postiats',
#    'stars': 130,
#    'starsToday': 0},
#   {'author': 'chrisdone',
#    'desc': 'Examples from Introduction to Programming in ATS',
#    'forks': 1,
#    'lang': 'ATS',
#    'repo': 'ats-examples',
#    'repoLink': '/chrisdone/ats-examples',
#    'stars': 16,
#    'starsToday': 0},
#   {'author': 'deech',
#    'desc': '',
#    'forks': 2,
#    'lang': 'ATS',
#    'repo': 'ATSPresentation',
#    'repoLink': '/deech/ATSPresentation',
#    'stars': 10,
#    'starsToday': 0},
#   {'author': 'metasepi',
#    'desc': 'generate ATS interface from C code',
#    'forks': 0,
#    'lang': 'ATS',
#    'repo': 'c2ats',
#    'repoLink': '/metasepi/c2ats',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'githwxi',
#    'desc': 'This repository is primarily for testing ATS2 on various platforms',
#    'forks': 3,
#    'lang': 'ATS',
#    'repo': 'ATS-Postiats-test',
#    'repoLink': '/githwxi/ATS-Postiats-test',
#    'stars': 5,
#    'starsToday': 0},
#   {'author': 'steinwaywhw',
#    'desc': 'A parsing combinator library.',
#    'forks': 0,
#    'lang': 'ATS',
#    'repo': 'ats-parcc',
#    'repoLink': '/steinwaywhw/ats-parcc',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'wdblair',
#    'desc': 'Another implementation of ATS',
#    'forks': 29,
# ...
#    'stars': 16,
#    'starsToday': 0},
#   {'author': 'fasterthanlime',
#    'desc': 'GTK2 bindings for ooc',
#    'forks': 6,
#    'lang': 'ooc',
#    'repo': 'ooc-gtk',
#    'repoLink': '/fasterthanlime/ooc-gtk',
#    'stars': 14,
#    'starsToday': 0},
#   {'author': 'joshthecoder',
#    'desc': 'A template engine for the ooc programming language. Inspired by Mustache and CTemplates.',
#    'forks': 5,
#    'lang': 'ooc',
#    'repo': 'mustang',
#    'repoLink': '/joshthecoder/mustang',
#    'stars': 12,
#    'starsToday': 0},
#   {'author': 'fasterthanlime',
#    'desc': 'flexible game engine in ooc, with an ingame console to adjust everything in realtime',
#    'forks': 2,
#    'lang': 'ooc',
#    'repo': 'inception-engine',
#    'repoLink': '/fasterthanlime/inception-engine',
#    'stars': 11,
#    'starsToday': 0},
#   {'author': 'fasterthanlime',
#    'desc': 'A small JIT-compiler written in ooc, for ooc (providing closures and partials)',
#    'forks': 4,
#    'lang': 'ooc',
#    'repo': 'yajit',
#    'repoLink': '/fasterthanlime/yajit',
#    'stars': 11,
#    'starsToday': 0},
#   {'author': 'ooc',
#    'desc': 'ooc development kit - collections, text manipulation, math, crypto, os - all nice and portable',
#    'forks': 1,
#    'lang': 'ooc',
#    'repo': 'llamacore',
#    'repoLink': '/ooc/llamacore',
#    'stars': 10,
#    'starsToday': 0},
#   {'author': 'joshthecoder',
#    'desc': 'A web application and server specification for ooc',
#    'forks': 2,
#    'lang': 'ooc',
#    'repo': 'ooc-web',
#    'repoLink': '/joshthecoder/ooc-web',
#    'stars': 10,
#    'starsToday': 0},
#   {'author': 'ooc-lang',
#    'desc': '📦 sam keeps your ooc repos up-to-date',
#    'forks': 13,
#    'lang': 'ooc',
#    'repo': 'sam',
#    'repoLink': '/ooc-lang/sam',
#    'stars': 9,
#    'starsToday': 0},
#   {'author': 'danopia',
#    'desc': 'Libcairo bindings for ooc',
#    'forks': 23,
#    'lang': 'ooc',
#    'repo': 'ooc-cairo',
#    'repoLink': '/danopia/ooc-cairo',
#    'stars': 9,
#    'starsToday': 0},
#   {'author': 'fredreichbier',
#    'desc': 'yajl binding for ooc',
#    'forks': 4,
#    'lang': 'ooc',
#    'repo': 'ooc-yajl',
#    'repoLink': '/fredreichbier/ooc-yajl',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'fasterthanlime',
#    'desc': 'Running ooc with scissors',
#    'forks': 1,
#    'lang': 'ooc',
#    'repo': 'scissors',
#    'repoLink': '/fasterthanlime/scissors',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'OneSadCookie',
#    'desc': 'GLEW (OpenGL) bindings for the ooc programming language',
#    'forks': 4,
#    'lang': 'ooc',
#    'repo': 'ooc-glew',
#    'repoLink': '/OneSadCookie/ooc-glew',
#    'stars': 8,
#    'starsToday': 0},
#   {'author': 'fasterthanlime',
#    'desc': 'And thus, all llamaistas went their own ways, creating their own languages, leaving the mothership which they loved and lived for.',
#    'forks': 2,
#    'lang': 'ooc',
#    'repo': 'decadence',
#    'repoLink': '/fasterthanlime/decadence',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'fasterthanlime',
#    'desc': 'Torrent client daemon + user-friendly web application to facilitate content search, download and streaming',
#    'forks': 1,
#    'lang': 'ooc',
#    'repo': 'fallacious',
#    'repoLink': '/fasterthanlime/fallacious',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'eagle2com',
#    'desc': 'Graphical and Physical engine written in ooc 0.3',
#    'forks': 2,
#    'lang': 'ooc',
#    'repo': 'Stirling3d',
#    'repoLink': '/eagle2com/Stirling3d',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'fredreichbier',
#    'desc': 'lua binding for ooc',
#    'forks': 1,
#    'lang': 'ooc',
#    'repo': 'ooc-lua',
#    'repoLink': '/fredreichbier/ooc-lua',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'fredreichbier',
#    'desc': 'command line option parsing for ooc',
#    'forks': 5,
#    'lang': 'ooc',
#    'repo': 'optparse',
#    'repoLink': '/fredreichbier/optparse',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'fasterthanlime',
#    'desc': 'ØMQ bindings for ooc',
#    'forks': 2,
#    'lang': 'ooc',
#    'repo': 'ooc-zeromq',
#    'repoLink': '/fasterthanlime/ooc-zeromq',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'solson',
#    'desc': 'ooc bindings for LLVM',
#    'forks': 3,
#    'lang': 'ooc',
#    'repo': 'ooc-llvm',
#    'repoLink': '/solson/ooc-llvm',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'fredreichbier',
#    'desc': 'package management for ooc',
#    'forks': 4,
#    'lang': 'ooc',
#    'repo': 'reincarnate',
#    'repoLink': '/fredreichbier/reincarnate',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'fasterthanlime',
#    'desc': 'ooc compatibility kit - test suite and tools to verify the compliance of an ooc implementation',
#    'forks': 1,
#    'lang': 'ooc',
#    'repo': 'bootcamp',
#    'repoLink': '/fasterthanlime/bootcamp',
#    'stars': 6,
#    'starsToday': 0}],
#  'reStructuredText': [],
#  'wisp': [{'author': 'Gozala',
#    'desc': 'A little Clojure-like LISP in JavaScript',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/Gozala/wisp',
#    'stars': 791,
#    'starsToday': 0},
#   {'author': 'h2non',
#    'desc': 'Small and generic functional helper library for node.js and browsers',
#    'forks': 3,
#    'lang': 'wisp',
#    'repo': 'hu',
#    'repoLink': '/h2non/hu',
#    'stars': 15,
#    'starsToday': 0},
#   {'author': 'h2non',
#    'desc': 'Tiny library for asynchronous control-flow in node and browsers',
#    'forks': 1,
#    'lang': 'wisp',
#    'repo': 'fw',
#    'repoLink': '/h2non/fw',
#    'stars': 5,
#    'starsToday': 0},
#   {'author': 'h2non',
#    'desc': 'Micro library for dependency injection and inversion of control containers in node and browsers',
#    'forks': 0,
#    'lang': 'wisp',
#    'repo': 'injecty',
#    'repoLink': '/h2non/injecty',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'h2non',
#    'desc': 'Tiny promise library mostly compatible with Promise/A+ spec and ES6',
#    'forks': 0,
#    'lang': 'wisp',
#    'repo': 'promitto',
#    'repoLink': '/h2non/promitto',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'leizongmin',
#    'desc': 'HTTP代理服务器',
#    'forks': 1,
#    'lang': 'wisp',
#    'repo': 'http-proxy-server',
#    'repoLink': '/leizongmin/http-proxy-server',
#    'stars': 2,
#    'starsToday': 0},
#   {'author': 'JeremS',
#    'desc': 'Utility to compile wisp files.',
#    'forks': 1,
#    'lang': 'wisp',
#    'repo': 'wispc',
#    'repoLink': '/JeremS/wispc',
#    'stars': 2,
#    'starsToday': 0},
#   {'author': 'peterwestmacott',
#    'desc': 'Homoiconic JS with clojure syntax, s-expressions & macros',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/peterwestmacott/wisp',
#    'stars': 2,
#    'starsToday': 0},
#   {'author': 'jamiepg1',
#    'desc': 'Utility to compile wisp files.',
#    'forks': 1,
#    'lang': 'wisp',
#    'repo': 'wispc',
#    'repoLink': '/jamiepg1/wispc',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'didhe',
#    'desc': 'Homoiconic JS with clojure syntax, s-expressions & macros',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/didhe/wisp',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'Johnicholas',
#    'desc': 'Homoiconic JS with clojure syntax, s-expressions & macros',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/Johnicholas/wisp',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'bamboo',
#    'desc': 'Homoiconic JS with clojure syntax, s-expressions & macros',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/bamboo/wisp',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'johnmorreli',
#    'desc': 'Homoiconic JS with clojure syntax, s-expressions & macros',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/johnmorreli/wisp',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'jacereda',
#    'desc': 'Homoiconic JS with clojure syntax, s-expressions & macros',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/jacereda/wisp',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'whacked',
#    'desc': 'a freaking json editor for jquery using wisp',
#    'forks': 1,
#    'lang': 'wisp',
#    'repo': 'freaking-json-editor',
#    'repoLink': '/whacked/freaking-json-editor',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'bwhmather',
#    'desc': 'Homoiconic JS with clojure syntax, s-expressions & macros',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/bwhmather/wisp',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'spion',
#    'desc': 'Homoiconic JS with clojure syntax, s-expressions & macros',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/spion/wisp',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'bertrandk',
#    'desc': 'Homoiconic JS with clojure syntax, s-expressions & macros',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/bertrandk/wisp',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'jamiepg1',
#    'desc': 'wisp dummy code',
#    'forks': 1,
#    'lang': 'wisp',
#    'repo': 'wisp-playground',
#    'repoLink': '/jamiepg1/wisp-playground',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'jamiepg1',
#    'desc': 'Source for my personal website at zitao.ca.',
#    'forks': 1,
#    'lang': 'wisp',
#    'repo': 'zitao.ca',
#    'repoLink': '/jamiepg1/zitao.ca',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'TEAM-CTHULHU',
#    'desc': 'Homoiconic JS with clojure syntax, s-expressions & macros. Check out the Google Plus Community:',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/TEAM-CTHULHU/wisp',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'jamiepg1',
#    'desc': 'Homoiconic JS with clojure syntax, s-expressions & macros',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/jamiepg1/wisp',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'thehydroimpulse',
#    'desc': 'Homoiconic JS with clojure syntax, s-expressions & macros',
#    'forks': 53,
#    'lang': 'wisp',
#    'repo': 'wisp',
#    'repoLink': '/thehydroimpulse/wisp',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'wynemo',
#    'desc': 'wisp dummy code',
#    'forks': 1,
#    'lang': 'wisp',
#    'repo': 'wisp-playground',
#    'repoLink': '/wynemo/wisp-playground',
#    'stars': 1,
#    'starsToday': 0},
#   {'author': 'jamiepg1',
#    'desc': 'HTTP代理服务器',
#    'forks': 1,
#    'lang': 'wisp',
#    'repo': 'http-proxy-server',
#    'repoLink': '/jamiepg1/http-proxy-server',
#    'stars': 1,
#    'starsToday': 0}],
#  'xBase': [{'author': 'imsys',
#    'desc': 'JSON support for ADVPL',
#    'forks': 18,
#    'lang': 'xBase',
#    'repo': 'JSON-ADVPL',
#    'repoLink': '/imsys/JSON-ADVPL',
#    'stars': 22,
#    'starsToday': 0},
#   {'author': 'NaldoDj',
#    'desc': 'Exemplos de Programas, Classes e funções em ADVPL',
#    'forks': 20,
#    'lang': 'xBase',
#    'repo': 'BlackTDN',
#    'repoLink': '/NaldoDj/BlackTDN',
#    'stars': 17,
#    'starsToday': 0},
#   {'author': 'dan-atilio',
#    'desc': 'Fontes criados de AdvPL para o Terminal de Informação',
#    'forks': 15,
#    'lang': 'xBase',
#    'repo': 'AdvPL',
#    'repoLink': '/dan-atilio/AdvPL',
#    'stars': 15,
#    'starsToday': 0},
#   {'author': 'nginformatica',
#    'desc': 'An AdvPL debugger written in AdvPL',
#    'forks': 6,
#    'lang': 'xBase',
#    'repo': 'advpl-debugger',
#    'repoLink': '/nginformatica/advpl-debugger',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'imsys',
#    'desc': 'Protheus Header files',
#    'forks': 7,
#    'lang': 'xBase',
#    'repo': 'Protheus-Include',
#    'repoLink': '/imsys/Protheus-Include',
#    'stars': 7,
#    'starsToday': 0},
#   {'author': 'osantana-archive',
#    'desc': '(Velharias) Sistema para controle de fiado em cantinas escolares',
#    'forks': 0,
#    'lang': 'xBase',
#    'repo': 'siscan',
#    'repoLink': '/osantana-archive/siscan',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'QuimFerrer',
#    'desc': 'Normativa Sepa',
#    'forks': 7,
#    'lang': 'xBase',
#    'repo': 'sepa',
#    'repoLink': '/QuimFerrer/sepa',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'fdbozzo',
#    'desc': 'Visual FoxPro 9 Binary to Text and Text to Binary converter. Replacement for SCCText(X) and TwoFox that is bi-directional (Text is editable)',
#    'forks': 3,
#    'lang': 'xBase',
#    'repo': 'foxbin2prg',
#    'repoLink': '/fdbozzo/foxbin2prg',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'sait',
#    'desc': 'Json encoder and decoder for VFP Visual Fox Pro',
#    'forks': 4,
#    'lang': 'xBase',
#    'repo': 'vfpjson',
#    'repoLink': '/sait/vfpjson',
#    'stars': 6,
#    'starsToday': 0},
#   {'author': 'nginformatica',
#    'desc': 'JSON parser written in and for TOTVS AdvPL',
#    'forks': 2,
#    'lang': 'xBase',
#    'repo': 'json-advpl',
#    'repoLink': '/nginformatica/json-advpl',
#    'stars': 5,
#    'starsToday': 0},
#   {'author': 'StevenBlack',
#    'desc': "Tom Rettig's Envlib library for Visual FoxPro, first released in 1995, is modernized and carried-forward.",
#    'forks': 1,
#    'lang': 'xBase',
#    'repo': 'envLib',
#    'repoLink': '/StevenBlack/envLib',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'GillesK',
#    'desc': 'Framework OO para Protheus Advpl: ORM, importação CSV, Coleção, Test Unitario e mais',
#    'forks': 3,
#    'lang': 'xBase',
#    'repo': 'Protheus-Advpl-OO-Framework',
#    'repoLink': '/GillesK/Protheus-Advpl-OO-Framework',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'ColiseoSoftware',
#    'desc': 'A set of tools for Visual FoxPro implementing the most common internet protocols',
#    'forks': 3,
#    'lang': 'xBase',
#    'repo': 'ifox',
#    'repoLink': '/ColiseoSoftware/ifox',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'Sandokansan',
#    'desc': 'Ludem Dare #35',
#    'forks': 1,
#    'lang': 'xBase',
#    'repo': 'ld35',
#    'repoLink': '/Sandokansan/ld35',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'mikepotjer',
#    'desc': 'Git utilities for VFP, designed to work within the Thor repository',
#    'forks': 1,
#    'lang': 'xBase',
#    'repo': 'vfp-git-utils',
#    'repoLink': '/mikepotjer/vfp-git-utils',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'FoxInCloud',
#    'desc': 'FoxInCloud public layer',
#    'forks': 3,
#    'lang': 'xBase',
#    'repo': 'FoxInCloud-AB',
#    'repoLink': '/FoxInCloud/FoxInCloud-AB',
#    'stars': 4,
#    'starsToday': 0},
#   {'author': 'NaldoDj',
#    'desc': 'Classe em (x)Harbour/ADVPL para calcular números absurdamente grandes',
#    'forks': 3,
#    'lang': 'xBase',
#    'repo': 'tBigNumber',
#    'repoLink': '/NaldoDj/tBigNumber',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'MRonaldo',
#    'desc': 'M.,Ronaldo Tools: Componentes e Classes para Harbour ( Boleto Bancario e Sistemas de Impressão )',
#    'forks': 1,
#    'lang': 'xBase',
#    'repo': 'MR-Tools',
#    'repoLink': '/MRonaldo/MR-Tools',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'skiptirengu',
#    'desc': 'Biblioteca ORM (Object Relational Mapping) desenvolvida inteiramente em ADVPL!',
#    'forks': 0,
#    'lang': 'xBase',
#    'repo': 'advpl-orm',
#    'repoLink': '/skiptirengu/advpl-orm',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'RickCHodgin',
#    'desc': 'In VFP, launch a small app to show an animated gif in a separate process for the duration of a task',
#    'forks': 3,
#    'lang': 'xBase',
#    'repo': 'guithread',
#    'repoLink': '/RickCHodgin/guithread',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'nginformatica',
#    'desc': "An AdvPL port of Haskell's Prelude library",
#    'forks': 4,
#    'lang': 'xBase',
#    'repo': 'prelude-advpl',
#    'repoLink': '/nginformatica/prelude-advpl',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'siga0984',
#    'desc': 'Fontes AdvPL do Bog "Tudo em AdvPL"',
#    'forks': 6,
#    'lang': 'xBase',
#    'repo': 'Blog',
#    'repoLink': '/siga0984/Blog',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'tfonrouge',
#    'desc': 'Text User Interface Library for the Harbour compiler',
#    'forks': 1,
#    'lang': 'xBase',
#    'repo': 'HBTui',
#    'repoLink': '/tfonrouge/HBTui',
#    'stars': 3,
#    'starsToday': 0},
#   {'author': 'lynx68',
#    'desc': 'Open source multiplatform simple invoice system',
#    'forks': 0,
#    'lang': 'xBase',
#    'repo': 'fenix',
#    'repoLink': '/lynx68/fenix',
#    'stars': 2,
#    'starsToday': 0},
#   {'author': 'cakyus',
#    'desc': 'konversi cursor ke ms excell 2007',
#    'forks': 2,
#    'lang': 'xBase',
#    'repo': 'cursor2xlsx',
#    'repoLink': '/cakyus/cursor2xlsx',
#    'stars': 2,
#    'starsToday': 0}]}
